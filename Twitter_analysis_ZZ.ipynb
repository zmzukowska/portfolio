# %% [markdown]
# # Load libraries

# %%
# for data transformation
import pandas as pd
import numpy as np

#to manipulate strings
import re
import string

#for visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# for test prepocessing
import nltk #natural language toolkit
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# for sentiments
from textblob import TextBlob

#for using the bag-of-words model
from sklearn.feature_extraction.text import CountVectorizer

#download dictionaries
nltk.download('punkt')
nltk.download ('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Decoded\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Decoded\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Decoded\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Reading the data

# %%
data = pd.read_csv('apple-tweets.csv')
data.head()
# Out:
#      user_id     status_id  created_at   screen_name  \
# 0  5746452.0  1.090000e+18  1548799817  waltmossberg
# 1  5746452.0  1.090000e+18  1548800328  waltmossberg
# 2  5746452.0  1.090000e+18  1548802301  waltmossberg
# 3  5746452.0  1.090000e+18  1548800242  waltmossberg
# 4  1175221.0  1.090000e+18  1548737368     digiphile
#
#                                                 text              source  \
# 0  It’s true that @Apple likely overpriced the la...    Twitter for iPad
# 1                   @AaronSuplizio @Apple Yes it is.    Twitter for iPad
# 2  @mvigod @Apple As I have said many times here,...    Twitter for iPad
# 3  I’m not saying that @Apple doesn’t have proble...    Twitter for iPad
# 4  @DaveLeeBBC @Apple @NYGovCuomo Nor I; saw it g...  Twitter for iPhone
#
#    display_text_width  reply_to_status_id  reply_to_user_id  \
# 0                 279                 NaN               NaN
# 1                  10        1.090000e+18      2.365419e+07
# 2                 259        1.090000e+18      2.224800e+08
# 3                 270        1.090000e+18      5.746452e+06
# 4                  88        1.090000e+18      1.251786e+09
#
#   reply_to_screen_name                        ...                          \
# 0                  NaN                        ...
# 1        AaronSuplizio                        ...
# 2               mvigod                        ...
# 3         waltmossberg                        ...
# 4           DaveLeeBBC                        ...
#
#    statuses_count  favourites_count  account_created_at  verified  \
# 0           21783             31007          1178213411      True
# 1           21783             31007          1178213411      True
# 2           21783             31007          1178213411      True
# 3           21783             31007          1178213411      True
# 4          165604            108196          1173899540      True
#
#                profile_url                               profile_expanded_url  \
# 0  https://t.co/AH9VhHsJmY  http://www.theverge.com/label/walt-mossberg-verge
# 1  https://t.co/AH9VhHsJmY  http://www.theverge.com/label/walt-mossberg-verge
# 2  https://t.co/AH9VhHsJmY  http://www.theverge.com/label/walt-mossberg-verge
# 3  https://t.co/AH9VhHsJmY  http://www.theverge.com/label/walt-mossberg-verge
# 4  https://t.co/QWOxhaw2kk                      https://digiphile.info/about/
#
#   account_lang                                 profile_banner_url  \
# 0           en  https://pbs.twimg.com/profile_banners/5746452/...
# 1           en  https://pbs.twimg.com/profile_banners/5746452/...
# 2           en  https://pbs.twimg.com/profile_banners/5746452/...
# 3           en  https://pbs.twimg.com/profile_banners/5746452/...
# 4           en  https://pbs.twimg.com/profile_banners/1175221/...
#
#                               profile_background_url  \
# 0   http://abs.twimg.com/images/themes/theme9/bg.gif
# 1   http://abs.twimg.com/images/themes/theme9/bg.gif
# 2   http://abs.twimg.com/images/themes/theme9/bg.gif
# 3   http://abs.twimg.com/images/themes/theme9/bg.gif
# 4  http://abs.twimg.com/images/themes/theme15/bg.png
#
#                                    profile_image_url
# 0  http://pbs.twimg.com/profile_images/4637351296...
# 1  http://pbs.twimg.com/profile_images/4637351296...
# 2  http://pbs.twimg.com/profile_images/4637351296...
# 3  http://pbs.twimg.com/profile_images/4637351296...
# 4  http://pbs.twimg.com/profile_images/1076306605...
#
# [5 rows x 88 columns]

# %%
tweets =data['text']

# %%
tweets[0]
# Out:
# 'It’s true that @Apple likely overpriced the latest iPhones in a mature market, especially in China. And that it therefore overestimated revenues and earnings. But, people, please remember that the shortfall meant they took in “only” $84 billion in 90 days instead of $93 billion.'

# %%
tweets[1]
# Out:
# '@AaronSuplizio @Apple Yes it is.'

# %%
tweets[99]
# Out:
# '@Apple Waaiiiiit? Is this real life?'

# %%
tweets[150]
# Out:
# 'Joining @TeamCavuto on @FoxBusiness to talk @Apple earning and Facetime. Hope you can tune in. :-)'

# %% [markdown]
# # Data cleaning & preprocessing

# %%
sample = 'My first sentence.      My SECOND SENTENCE!!! Cows and cars became had been... @Apple you suck!'

# %%
sample
# Out:
# 'My first sentence.      My SECOND SENTENCE!!! Cows and cars became had been... @Apple you suck!'

# %%
type(sample)
# Out:
# str

# %%
sample.lower()
# Out:
# 'my first sentence.      my second sentence!!! cows and cars became had been... @apple you suck!'

# %%
sample.upper()
# Out:
# 'MY FIRST SENTENCE.      MY SECOND SENTENCE!!! COWS AND CARS BECAME HAD BEEN... @APPLE YOU SUCK!'

# %%
re.sub('Cows','horses',sample)
# Out:
# 'My first sentence.      My SECOND SENTENCE!!! horses and cars became had been... @Apple you suck!'

# %%
#regex = regular expressions
re.sub('\s+',' ',sample)
# Out:
# 'My first sentence. My SECOND SENTENCE!!! Cows and cars became had been... @Apple you suck!'

# %%
words = word_tokenize(sample)
type(words)
# Out:
# list

# %%
sent_tokenize(sample)
# Out:
# ['My first sentence.',
#  'My SECOND SENTENCE!!!',
#  'Cows and cars became had been... @Apple you suck!']

# %%
words = word_tokenize(sample)

[WordNetLemmatizer().lemmatize(w, pos ='v') for w in words] #reduces to inflectional form
# Out:
# ['My',
#  'first',
#  'sentence',
#  '.',
#  'My',
#  'SECOND',
#  'SENTENCE',
#  '!',
#  '!',
#  '!',
#  'Cows',
#  'and',
#  'cars',
#  'become',
#  'have',
#  'be',
#  '...',
#  '@',
#  'Apple',
#  'you',
#  'suck',
#  '!']

# %%
#stopwords.words('english')

# %%
def clean(text):
    
    # Lowercase everything
    text = text.lower()
    
    #remove extra space
    text = re.sub('\s+',' ', text)
    
    #tokenize
    words = word_tokenize(text)
    
    words = [w for w in words if w.isalpha()] #keep alphabetical characters only
        
    # Lemmetize it
    words = [WordNetLemmatizer().lemmatize(w,pos = 'n') for w in words]
    words = [WordNetLemmatizer().lemmatize(w,pos = 'v') for w in words]
    words = [WordNetLemmatizer().lemmatize(w,pos = 'a') for w in words]
     
    # remove stopwords
    words = [w for w in words if w not in stopwords.words('english')]
    
    # return as text
    text = ' '.join(words)
    
    return text

# %%
tweets = tweets.apply(lambda x: clean(x))

# %%
tweets[0]
# Out:
# 'true apple likely overprice late iphones mature market especially china therefore overestimate revenue earn people please remember shortfall mean take billion day instead billion'

# %% [markdown]
# # Visualisation & Modelling

# %%
# Bag of words model
vector = CountVectorizer(max_features = 5000, min_df = 0.01)

vector
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=5000, min_df=0.01,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
bag_of_words = vector.fit_transform(tweets)

bag_of_words #9991 docs/tweets vs 12256 unique terms/features
# Out:
# <9991x162 sparse matrix of type '<class 'numpy.int64'>'
# 	with 50239 stored elements in Compressed Sparse Row format>

# %%
vector.get_feature_names()
# Out:
# ['add',
#  'airpods',
#  'allow',
#  'already',
#  'also',
#  'always',
#  'amp',
#  'android',
#  'another',
#  'answer',
#  'app',
#  'apple',
#  'applesupport',
#  'back',
#  'bad',
#  'battery',
#  'best',
#  'big',
#  'break',
#  'bug',
#  'buy',
#  'ca',
#  'call',
#  'camera',
#  'change',
#  'charge',
#  'come',
#  'company',
#  'could',
#  'customer',
#  'data',
#  'day',
#  'device',
#  'disable',
#  'doe',
#  'eavesdrop',
#  'even',
#  'ever',
#  'every',
#  'facebook',
#  'facetime',
#  'feature',
#  'find',
#  'first',
#  'fix',
#  'fuck',
#  'get',
#  'give',
#  'glitch',
#  'go',
#  'good',
#  'google',
#  'great',
#  'group',
#  'guy',
#  'ha',
#  'happen',
#  'hear',
#  'help',
#  'hey',
#  'http',
#  'io',
#  'ipad',
#  'iphone',
#  'iphones',
#  'issue',
#  'job',
#  'keep',
#  'know',
#  'last',
#  'late',
#  'let',
#  'life',
#  'like',
#  'listen',
#  'lol',
#  'long',
#  'look',
#  'lose',
#  'love',
#  'mac',
#  'make',
#  'many',
#  'market',
#  'mean',
#  'microsoft',
#  'money',
#  'month',
#  'much',
#  'music',
#  'na',
#  'need',
#  'never',
#  'new',
#  'next',
#  'old',
#  'one',
#  'pay',
#  'people',
#  'phone',
#  'please',
#  'price',
#  'privacy',
#  'pro',
#  'problem',
#  'product',
#  'put',
#  'really',
#  'release',
#  'report',
#  'right',
#  'run',
#  'sale',
#  'samsung',
#  'say',
#  'screen',
#  'security',
#  'see',
#  'sell',
#  'send',
#  'service',
#  'shit',
#  'shotoniphone',
#  'show',
#  'since',
#  'software',
#  'someone',
#  'something',
#  'start',
#  'still',
#  'stop',
#  'store',
#  'support',
#  'take',
#  'talk',
#  'tech',
#  'tell',
#  'thank',
#  'thing',
#  'think',
#  'time',
#  'today',
#  'try',
#  'turn',
#  'update',
#  'upgrade',
#  'use',
#  'user',
#  'via',
#  'video',
#  'wa',
#  'wait',
#  'want',
#  'watch',
#  'way',
#  'week',
#  'well',
#  'win',
#  'without',
#  'work',
#  'would',
#  'year']

# %%
sum_words = bag_of_words.sum(axis = 0)

words_freq = [(word, sum_words[0, idx]) for word, idx in vector.vocabulary_.items()]

words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)

words_freq
# Out:
# [('apple', 11473),
#  ('http', 3499),
#  ('iphone', 1271),
#  ('get', 1115),
#  ('facetime', 1007),
#  ('phone', 935),
#  ('new', 705),
#  ('like', 638),
#  ('make', 635),
#  ('fix', 622),
#  ('go', 601),
#  ('wa', 578),
#  ('use', 531),
#  ('need', 528),
#  ('bug', 518),
#  ('applesupport', 501),
#  ('good', 496),
#  ('ha', 490),
#  ('one', 481),
#  ('work', 432),
#  ('time', 431),
#  ('call', 431),
#  ('amp', 414),
#  ('think', 413),
#  ('people', 412),
#  ('update', 404),
#  ('would', 393),
#  ('know', 364),
#  ('please', 353),
#  ('shit', 348),
#  ('take', 340),
#  ('say', 338),
#  ('app', 334),
#  ('year', 326),
#  ('want', 324),
#  ('thank', 323),
#  ('even', 320),
#  ('buy', 317),
#  ('still', 310),
#  ('let', 294),
#  ('privacy', 294),
#  ('see', 293),
#  ('come', 292),
#  ('google', 290),
#  ('really', 286),
#  ('android', 282),
#  ('watch', 280),
#  ('back', 277),
#  ('answer', 272),
#  ('product', 271),
#  ('day', 258),
#  ('fuck', 257),
#  ('user', 255),
#  ('io', 250),
#  ('love', 248),
#  ('price', 244),
#  ('look', 242),
#  ('try', 238),
#  ('pay', 237),
#  ('issue', 232),
#  ('give', 228),
#  ('way', 228),
#  ('company', 226),
#  ('shotoniphone', 226),
#  ('right', 225),
#  ('thing', 224),
#  ('hear', 223),
#  ('much', 222),
#  ('device', 221),
#  ('could', 219),
#  ('service', 215),
#  ('doe', 210),
#  ('ipad', 205),
#  ('great', 194),
#  ('battery', 190),
#  ('feature', 185),
#  ('facebook', 184),
#  ('well', 182),
#  ('hey', 174),
#  ('group', 173),
#  ('store', 172),
#  ('allow', 169),
#  ('win', 167),
#  ('also', 167),
#  ('disable', 166),
#  ('via', 166),
#  ('without', 166),
#  ('bad', 164),
#  ('stop', 164),
#  ('find', 164),
#  ('listen', 164),
#  ('never', 163),
#  ('happen', 162),
#  ('change', 161),
#  ('every', 160),
#  ('samsung', 159),
#  ('big', 158),
#  ('turn', 155),
#  ('someone', 154),
#  ('screen', 153),
#  ('something', 153),
#  ('start', 152),
#  ('iphones', 151),
#  ('customer', 151),
#  ('next', 150),
#  ('help', 150),
#  ('last', 150),
#  ('tell', 148),
#  ('charge', 148),
#  ('lol', 147),
#  ('sale', 144),
#  ('best', 144),
#  ('old', 140),
#  ('week', 136),
#  ('guy', 136),
#  ('tech', 136),
#  ('keep', 136),
#  ('pro', 135),
#  ('airpods', 133),
#  ('music', 132),
#  ('video', 131),
#  ('first', 130),
#  ('support', 129),
#  ('security', 128),
#  ('today', 127),
#  ('problem', 126),
#  ('mac', 126),
#  ('upgrade', 126),
#  ('late', 125),
#  ('market', 125),
#  ('ever', 124),
#  ('camera', 124),
#  ('wait', 123),
#  ('put', 122),
#  ('long', 122),
#  ('money', 122),
#  ('microsoft', 122),
#  ('another', 119),
#  ('software', 118),
#  ('data', 116),
#  ('report', 115),
#  ('add', 114),
#  ('eavesdrop', 114),
#  ('talk', 113),
#  ('na', 113),
#  ('job', 113),
#  ('many', 112),
#  ('release', 112),
#  ('month', 112),
#  ('since', 111),
#  ('run', 111),
#  ('glitch', 111),
#  ('sell', 110),
#  ('show', 108),
#  ('break', 108),
#  ('lose', 108),
#  ('life', 107),
#  ('ca', 107),
#  ('already', 104),
#  ('send', 104),
#  ('mean', 103),
#  ('always', 103)]

# %%
# ignoring top word (which is "apple" in this case)
top_words = words_freq[1:30]

for word, freq in top_words:
    print(word, freq)


word = []
count = []

for i, j in top_words: 
    word.append(i)
    count.append(j)


plt.figure(figsize = (10,10))

sns.barplot(x = count, y = word)
# Out:
# http 3499
# iphone 1271
# get 1115
# facetime 1007
# phone 935
# new 705
# like 638
# make 635
# fix 622
# go 601
# wa 578
# use 531
# need 528
# bug 518
# applesupport 501
# good 496
# ha 490
# one 481
# work 432
# time 431
# call 431
# amp 414
# think 413
# people 412
# update 404
# would 393
# know 364
# please 353
# shit 348

# %%
# wordcloud requires a dict with { word : frequency }
words_dict = {}
for k,v in top_words:
    words_dict[k] = int(v)

wordcloud = WordCloud(width=1000, height=500, background_color="white").generate_from_frequencies(words_dict)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Sentiments

# %%
tweets[0]
# Out:
# 'true apple likely overprice late iphones mature market especially china therefore overestimate revenue earn people please remember shortfall mean take billion day instead billion'

# %%
TextBlob(tweets[0]).sentiment
# Out:
# Sentiment(polarity=-0.027083333333333334, subjectivity=0.6729166666666666)

# %%
tweets[162]
# Out:
# 'new giveaway jewishladyblog enter win gift card apple http'

# %%
TextBlob(tweets[162]).sentiment
# Out:
# Sentiment(polarity=0.4681818181818182, subjectivity=0.42727272727272725)

# %%
sentiments = []

for tweet in tweets:
    analysis = TextBlob(tweet)
    sentiments.append(analysis.sentiment.polarity)



tweets_df = pd.DataFrame(tweets)

tweets_df['sentiments'] = sentiments

tweets_df
# Out:
#                                                    text  sentiments
# 0     true apple likely overprice late iphones matur...   -0.027083
# 1                               aaronsuplizio apple yes    0.000000
# 2     mvigod apple say many time regard multiple com...    0.000000
# 3     say apple problem challenge doe say perspectiv...    0.000000
# 4     daveleebbc apple nygovcuomo saw go track confi...    0.000000
# 5     apple ha disable group facetime http unexpecte...   -0.086061
# 6     wish amp apple tweet statement medium identify...   -0.300000
# 7                          word time fix amp apple http    0.000000
# 8     daveleebbc apple nygovcuomo use back want opin...   -0.025000
# 9     apple big welfare taker time billion tax favor...    0.000000
# 10    profit apple service per time bigbiz average i...   -0.150000
# 11    hollismulwrayv apple irs gross net revenue dep...    0.000000
# 12    apple outrageous gross profit margin report cn...   -0.375000
# 13    march wa newtonprotest apple hq protest cancel...    0.466667
# 14    aallan apple least io rule regulation enforcem...   -0.033333
# 15    come apple applesupport need call someone nong...    0.107143
# 16    hey apple doe iphone like autocorrect thanos t...    0.000000
# 17    apple promote post via apple waste chance conn...    0.000000
# 18    wonder ever read mention especially dataprivac...    0.000000
# 19                     apple twitter fee right lol http    0.542857
# 20    imho iphone user apple afford open applemusic ...    0.228571
# 21    oled expensive phone apple must offer customer...   -0.212500
# 22       te reason ditch iphone http applesupport apple    0.000000
# 23    hey apple wa ridicule friend today use sony un...    0.000000
# 24    well qualcomm make good argument apple play pu...    0.700000
# 25    apple applesupport please please please allow ...    0.166667
# 26    wonder apple watch series track bod workout sa...    0.000000
# 27    new giveaway jewishladyblog enter win gift car...    0.468182
# 28    new giveaway jewishladyblog enter win gift car...    0.468182
# 29    new giveaway jewishladyblog enter win gift car...    0.468182
# ...                                                 ...         ...
# 9961  almost fell apple xr trade offer today remembe...    0.000000
# 9962   apple go let people leave facetime video message    0.000000
# 9963                         apple never happen sit buy    0.000000
# 9964                         apple want need start save    0.000000
# 9965  patrioticmills trickle work perfectly company ...    0.400000
# 9966               apple stop probe search history cunt    0.000000
# 9967  sad new gold macbook air pink iphone x new app...   -0.081818
# 9968           tmobile apple think offer phone provider    0.000000
# 9969  macbook pro apple international plaza tampa fl...    0.000000
# 9970  apple dismissal selfdriving car employee signa...    0.000000
# 9971                              apple love commercial    0.250000
# 9972  something inherently exceptional go stand matt...    0.666667
# 9973  beerwhisperer aliciasinsight apple also ha goo...    0.666667
# 9974  intifada bdsmovement ginosocialist intel micro...   -0.133333
# 9975  jnjnews apple wireless radio frequency bravo e...    0.000000
# 9976  emeraldjeana apple take device apple store rep...    0.000000
# 9977  apple applesupport implement grid line set ima...    0.300000
# 9978                         apple feel accomplish http    0.000000
# 9979     jnjnews apple new study asbestos talcum powder    0.136364
# 9980  apple trade iphone something work good cost le...    0.325000
# 9981  amazon zacefron adrianalima amazonhelp microso...    0.400000
# 9982  surface spotify amazonhelp microsofthelps amaz...    0.400000
# 9983  doe matter notch iphone x apple timcook really...    0.500000
# 9984                                   apple true thing    0.350000
# 9985                                     apple stop spy    0.000000
# 9986                                         apple nope    0.000000
# 9987  jjhannanwriting apple apple ha become scientol...    0.000000
# 9988  get say apple love everything iphone se light ...    0.333333
# 9989  courtmejias raymondchung apple honda toyota go...    0.000000
# 9990  throw googleuk amazonuk apple focus tax avoida...    0.000000
#
# [9991 rows x 2 columns]

# %%
sns.distplot(tweets_df['sentiments'])
# Out:
# T:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# find most positive tweets
positive = tweets_df.sort_values(by = 'sentiments', ascending=False)
positive = positive.reset_index(drop=True)

positive
# Out:
#                                                    text  sentiments
# 0                            apple awesome look forward        1.00
# 1                                       apple wonderful        1.00
# 2     perfect even click image ar bali indonesia app...        1.00
# 3                                  apple look delicious        1.00
# 4                            apple one best ad ever see        1.00
# 5                                         apple awesome        1.00
# 6     applesupport apple problem iphones trade other...        1.00
# 7     ad cmos pick best congratulation airbnb apple ...        1.00
# 8                                        best ever http        1.00
# 9     instagram implantation volume bar x best could...        1.00
# 10                     ericajoy best apple feature ever        1.00
# 11    give apple two year ago best decision ever mak...        1.00
# 12    jason apple android try razer phone display aw...        1.00
# 13                 gregsdua apple might best tweet send        1.00
# 14    awesome million child parent incarcerate need ...        1.00
# 15                             apple best apple ad ever        1.00
# 16    magnet may best macos app think apple would bu...        1.00
# 17    ca believe apple ft answer others het privacy ...        1.00
# 18    apple shittiest iphone best offer nah upgrade ...        1.00
# 19           julieslick apple theadrianbelew superb job        1.00
# 20    poojahandatv awesome call apple facetime flaw ...        1.00
# 21    apple would take deal already xr girl ha best ...        1.00
# 22         x max wa best decision ever make thank apple        1.00
# 23    apple apple logic person ew sale person twenty...        1.00
# 24                                 apple hear plus best        1.00
# 25                  apple hear folk say best anyone say        1.00
# 26    gauravkheterpal apple help tab priceless alway...        1.00
# 27     charliebbucket apple iphone x max camera awesome        1.00
# 28    beckrsaunders apple think camera wa awesome be...        1.00
# 29                                  apple one best http        1.00
# ...                                                 ...         ...
# 9961                             apple colorblind moron       -0.80
# 9962  attain aetna mbr purchase apple watch pay aetn...       -0.80
# 9963  apple desperate promotion really pathetic phon...       -0.80
# 9964  hondacustsvc apple please interface problem ha...       -0.80
# 9965                    apple perhaps assist apple crap       -0.80
# 9966  apple applesupport gon na let ppl answer facet...       -0.80
# 9967     uberfacts ca delete macbooks thank apple idiot       -0.80
# 9968  nicksdjohnson apple butterfly keyboard everyon...       -0.80
# 9969  apple well bummer iphone sale crater apple bad...       -0.85
# 9970  apple ha bug allow eavesdrop phone please shut...       -0.85
# 9971  apple applesupport yr service pathetic u r hir...       -0.90
# 9972                           dam facetime apple nasty       -1.00
# 9973          wilderheartco apple arianagrande horrible       -1.00
# 9974  microsoft nutshell dreadful user experience co...       -1.00
# 9975  nasty facetime bug could allow others eavesdro...       -1.00
# 9976  vzwsupport either apple need fix conference ca...       -1.00
# 9977                     apple phone par lcd cruel joke       -1.00
# 9978          insane ever hear cybersecurity apple http       -1.00
# 9979  wire bug nasty happen differentiate apple act ...       -1.00
# 9980  maniltongya maple apple applesupport never exp...       -1.00
# 9981  apple tech company paint company pathetic way ...       -1.00
# 9982  dear apple result slowdown iphone sale china c...       -1.00
# 9983  apple sans credit still try get iron egregious...       -1.00
# 9984  applesupport terrible build quality apple acce...       -1.00
# 9985  everyone worry apple facetime glitch concern t...       -1.00
# 9986  sharatibken ftc qualcomm apple samsung assume ...       -1.00
# 9987  evil bastard apple make computer usa verge htt...       -1.00
# 9988  terrible everyone disable facetime apple need ...       -1.00
# 9989  arjwright apple understand default insane keep...       -1.00
# 9990      apple io release ha nasty surprise apple http       -1.00
#
# [9991 rows x 2 columns]

# %%
# find most negative tweets
negative = tweets_df.sort_values(by='sentiments', ascending=True)
negative = negative.reset_index(drop=True)

negative
# Out:
#                                                    text  sentiments
# 0     sharatibken ftc qualcomm apple samsung assume ...       -1.00
# 1     applesupport terrible build quality apple acce...       -1.00
# 2     evil bastard apple make computer usa verge htt...       -1.00
# 3             wilderheartco apple arianagrande horrible       -1.00
# 4         apple io release ha nasty surprise apple http       -1.00
# 5     dear apple result slowdown iphone sale china c...       -1.00
# 6     wire bug nasty happen differentiate apple act ...       -1.00
# 7     arjwright apple understand default insane keep...       -1.00
# 8     vzwsupport either apple need fix conference ca...       -1.00
# 9     maniltongya maple apple applesupport never exp...       -1.00
# 10    everyone worry apple facetime glitch concern t...       -1.00
# 11    terrible everyone disable facetime apple need ...       -1.00
# 12            insane ever hear cybersecurity apple http       -1.00
# 13                             dam facetime apple nasty       -1.00
# 14    apple tech company paint company pathetic way ...       -1.00
# 15                       apple phone par lcd cruel joke       -1.00
# 16    nasty facetime bug could allow others eavesdro...       -1.00
# 17    apple sans credit still try get iron egregious...       -1.00
# 18    microsoft nutshell dreadful user experience co...       -1.00
# 19    apple applesupport yr service pathetic u r hir...       -0.90
# 20    apple well bummer iphone sale crater apple bad...       -0.85
# 21    apple ha bug allow eavesdrop phone please shut...       -0.85
# 22    apple aetna create wellness program base apple...       -0.80
# 23    shierkahn rizzydraws beyondphere appstore appl...       -0.80
# 24                               apple colorblind moron       -0.80
# 25    attain aetna mbr purchase apple watch pay aetn...       -0.80
# 26    apple try service company yet base icloud stor...       -0.80
# 27                         jedive apple hate thing work       -0.80
# 28        hate charge phone use aux time bullshit apple       -0.80
# 29                   apple hate ad also phone look date       -0.80
# ...                                                 ...         ...
# 9961  reubstock google apple longnow ah well best ex...        1.00
# 9962       x max wa best decision ever make thank apple        1.00
# 9963                                  apple best iphone        1.00
# 9964  elonmusk hey want protect world economy partne...        1.00
# 9965                   apple excellent piece technology        1.00
# 9966  apple request cash make give immaculate perfec...        1.00
# 9967  gauravkheterpal apple help tab priceless alway...        1.00
# 9968                         apple one best ad ever see        1.00
# 9969                   alexisohanian hola apple awesome        1.00
# 9970  instagram implantation volume bar x best could...        1.00
# 9971  gt gt ecosystem ipad simply magnificent lt lt ...        1.00
# 9972                                      apple awesome        1.00
# 9973  apple shittiest iphone best offer nah upgrade ...        1.00
# 9974  apple dear apple upgrade one post video one co...        1.00
# 9975  actormadhavan could best use case apple improv...        1.00
# 9976  jason apple android try razer phone display aw...        1.00
# 9977  nytorv apple get mine thats way could justify ...        1.00
# 9978  apple apple logic person ew sale person twenty...        1.00
# 9979  poojahandatv awesome call apple facetime flaw ...        1.00
# 9980  awesome million child parent incarcerate need ...        1.00
# 9981  michaelkammes sfcutters apple lacpug hmm desk ...        1.00
# 9982  apple ipad pro trick hey microsoft go enable h...        1.00
# 9983                   ericajoy best apple feature ever        1.00
# 9984               gregsdua apple might best tweet send        1.00
# 9985                  whoa apple best raidernation http        1.00
# 9986  apple would take deal already xr girl ha best ...        1.00
# 9987  magnet may best macos app think apple would bu...        1.00
# 9988                                    apple wonderful        1.00
# 9989  iphone xr battery life best ever experience we...        1.00
# 9990  ha best stream device apple google amazon appl...        1.00
#
# [9991 rows x 2 columns]

# %%
# other data dictionaries = vader
